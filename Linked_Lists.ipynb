# %% [markdown]
# <a href="https://colab.research.google.com/github/Eswari-21/LinkedList/blob/main/Linked_Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linked Lists
# #### Lists are Non Contagious DS
# #### Arrays are Contagious DS
# #### memory allocate
# #### access
#
# 1. Single Linked List
# 2. Double Linked List
# 3. Circular Linked List
#
# example
#
# class node :
#
#     def __init__ (self,data) :
#          self.data = data
#          self.next = None
#
# # Insertion  for the Single Linked List
# 1. At begin
# 2. At end
# 3. At location

# %% [markdown]
# ## Inserted at Being

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None
    def iab(self,data):
        newnode = Node(data)
        newnode.next = self.head
        self.head = newnode
        print(f" {data} inserted from begin.")
    def display(self):
        current = self.head
        if not current:
            print("LinkedList - empty")
            return
        while current:
            print(current.data, end="  ")
            current = current.next
        print("None")
l1 = LinkedList()
while True:
    print("\n LinkendList - Insert At begin...")
    print(" 1. insert")
    print(" 2. display")
    print("3. Exit")
    choice = input("enter ur choice:")
    if choice == '1':
        data = int(input("enter a value to insert"))
        l1.iab(data)
    elif choice == '2':
        l1.display()
    elif choice == '3':
        print("Exit the operation...")
        break
    else:
        print("enter only 1/2/3")
# Out:
#  LinkendList - Insert At begin...
#  1. insert
#  2. display
# 3. Exit
# enter ur choice:1
# enter a value to insert34
#  34 inserted from begin.
#
#  LinkendList - Insert At begin...
#  1. insert
#  2. display
# 3. Exit
# enter ur choice:1
# enter a value to insert21
#  21 inserted from begin.
#
#  LinkendList - Insert At begin...
#  1. insert
#  2. display
# 3. Exit
# enter ur choice:1
# enter a value to insert59
#  59 inserted from begin.
#
#  LinkendList - Insert At begin...
#  1. insert
#  2. display
# 3. Exit
# enter ur choice:1
# enter a value to insert7
#  7 inserted from begin.
#
#  LinkendList - Insert At begin...
#  1. insert
#  2. display
# 3. Exit
# enter ur choice:2
# 7  59  21  34  None
#
#  LinkendList - Insert At begin...
#  1. insert
#  2. display
# 3. Exit
# enter ur choice:3
# Exit the operation...

# %% [markdown]
# ## Inserted at End

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def iae(self, data):  # Insert at end
        newnode = Node(data)
        if self.head is None:
            self.head = newnode
            print(f"{data} inserted at end.")
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = newnode
        print(f"{data} inserted at end.")

    def display(self):
        if self.head is None:
            print("Linked list is empty.")
            return
        current = self.head
        print("Linked List Elements:")
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

# Menu-driven code
l1 = LinkedList()
while True:
    print("\nLinkedList - Insert At End...")
    print("1. Insert")
    print("2. Display")
    print("3. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        data = int(input("Enter a value to insert: "))
        l1.iae(data)
    elif choice == '2':
        l1.display()
    elif choice == '3':
        print("Exiting the operation...")
        break
    else:
        print("Enter only 1/2/3")
# Out:
# LinkedList - Insert At End...
# 1. Insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 32
# 32 inserted at end.
#
# LinkedList - Insert At End...
# 1. Insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 11
# 11 inserted at end.
#
# LinkedList - Insert At End...
# 1. Insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 65
# 65 inserted at end.
#
# LinkedList - Insert At End...
# 1. Insert
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 34
# 34 inserted at end.
#
# LinkedList - Insert At End...
# 1. Insert
# 2. Display
# 3. Exit
# Enter your choice: 2
# Linked List Elements:
# 32 -> 11 -> 65 -> 34 -> None
#
# LinkedList - Insert At End...
# 1. Insert
# 2. Display
# 3. Exit
# Enter your choice: 3
# Exiting the operation...

# %% [markdown]
# ## Position at the location

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_position(self, data, pos):
        newnode = Node(data)
        if pos <= 0:
            print("Invalid position. Must be >= 1.")
            return
        if pos == 1:
            newnode.next = self.head
            self.head = newnode
            print(f"{data} inserted at position {pos}.")
            return
        current = self.head
        count = 1
        while current is not None and count < pos - 1:
            current = current.next
            count += 1
        if current is None:
            print("Position out of bounds.")
        else:
            newnode.next = current.next
            current.next = newnode
            print(f"{data} inserted at position {pos}.")

    def display(self):
        if self.head is None:
            print("Linked list is empty.")
            return
        current = self.head
        print("Linked List Elements:")
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

# Menu-driven code
l1 = LinkedList()
while True:
    print("\nLinkedList - Insert At Specific Position")
    print("1. Insert at Position")
    print("2. Display")
    print("3. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        data = int(input("Enter a value to insert: "))
        pos = int(input("Enter the position to insert at: "))
        l1.insert_at_position(data, pos)
    elif choice == '2':
        l1.display()
    elif choice == '3':
        print("Exiting the operation...")
        break
    else:
        print("Enter only 1/2/3")
# Out:
# LinkedList - Insert At Specific Position
# 1. Insert at Position
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 32
# Enter the position to insert at: 1
# 32 inserted at position 1.
#
# LinkedList - Insert At Specific Position
# 1. Insert at Position
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 43
# Enter the position to insert at: 3
# Position out of bounds.
#
# LinkedList - Insert At Specific Position
# 1. Insert at Position
# 2. Display
# 3. Exit
# Enter your choice: 1
# Enter a value to insert: 21
# Enter the position to insert at: 2
# 21 inserted at position 2.
#
# LinkedList - Insert At Specific Position
# 1. Insert at Position
# 2. Display
# 3. Exit
# Enter your choice: 2
# Linked List Elements:
# 32 -> 21 -> None
#
# LinkedList - Insert At Specific Position
# 1. Insert at Position
# 2. Display
# 3. Exit
# Enter your choice: 3
# Exiting the operation...

# %% [markdown]
# # Search at the List

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert_at_position(self, data, pos):
        newnode = Node(data)
        if pos <= 0:
            print("Invalid position. Must be >= 1.")
            return
        if pos == 1:
            newnode.next = self.head
            self.head = newnode
            print(f"{data} inserted at position {pos}.")
            return
        current = self.head
        count = 1
        while current is not None and count < pos - 1:
            current = current.next
            count += 1
        if current is None:
            print("Position out of bounds.")
        else:
            newnode.next = current.next
            current.next = newnode
            print(f"{data} inserted at position {pos}.")

    def display(self):
        if self.head is None:
            print("Linked list is empty.")
            return
        current = self.head
        print("Linked List Elements:")
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

    def search(self, value):
        current = self.head
        position = 1
        while current:
            if current.data == value:
                print(f"Value {value} found at position {position}.")
                return
            current = current.next
            position += 1
        print(f"Value {value} not found in the list.")

# Menu-driven code
l1 = LinkedList()
while True:
    print("\nLinkedList Operations")
    print("1. Insert at Position")
    print("2. Display")
    print("3. Search")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        data = int(input("Enter a value to insert: "))
        pos = int(input("Enter the position to insert at: "))
        l1.insert_at_position(data, pos)
    elif choice == '2':
        l1.display()
    elif choice == '3':
        value = int(input("Enter the value to search for: "))
        l1.search(value)
    elif choice == '4':
        print("Exiting the operation...")
        break
    else:
        print("Enter only 1/2/3/4")
# Out:
# LinkedList Operations
# 1. Insert at Position
# 2. Display
# 3. Search
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 21
# Enter the position to insert at: 1
# 21 inserted at position 1.
#
# LinkedList Operations
# 1. Insert at Position
# 2. Display
# 3. Search
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 11
# Enter the position to insert at: 2
# 11 inserted at position 2.
#
# LinkedList Operations
# 1. Insert at Position
# 2. Display
# 3. Search
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 1
# Enter the position to insert at: 3
# 1 inserted at position 3.
#
# LinkedList Operations
# 1. Insert at Position
# 2. Display
# 3. Search
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 31
# Enter the position to insert at: 4
# 31 inserted at position 4.
#
# LinkedList Operations
# 1. Insert at Position
# 2. Display
# 3. Search
# 4. Exit
# Enter your choice: 2
# Linked List Elements:
# 21 -> 11 -> 1 -> 31 -> None
#
# LinkedList Operations
# ...

# %% [markdown]
# # Deleting operations for Single Linked List
#
# 1. at end
# 2. at beginning
# 3. by value

# %%
"Delete operation by value"


class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def iae(self, data):  # Insert at end
        newnode = Node(data)
        if self.head is None:
            self.head = newnode
            print(f"{data} inserted at end.")
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = newnode

    def deletevalue(self, key):
      current = self.head
      if not current:
        print(" Empty LL")
        return
      if current.data == key:
        self.head = current.next
        print(f"{key} deleted from the list")
        return # Added return here
      prev = None
      while current and current.data != key:
        prev = current
        current = current.next
      if not current:
        print(f"{key} not found in the list")
        return
      prev.next = current.next
      print(f"{key} deleted from the list")


    def display(self):
      current = self.head
      if not current:
        print("Linked list is empty.")
        return
      print("Linked List Elements:")
      while current:
        print(current.data, end=" -> ")
        current = current.next
      print("None")
l1 = LinkedList()
while True:
    print("\nLinkedList - Delete by value..")
    print("1. Insert")
    print("2. Delete by value")
    print("3. Display")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        data = int(input("Enter a value to insert: "))
        l1.iae(data)
    elif choice == '2':
        Key = int(input("Enter the value to delete: "))
        l1.deletevalue(Key)
    elif choice == '3':
        l1.display()
    elif choice == '4':
        print("Exiting the operation...")
        break
    else:
        print("Enter only 1/2/3/4")
# Out:
# LinkedList - Delete by value..
# 1. Insert
# 2. Delete by value
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 12
# 12 inserted at end.
#
# LinkedList - Delete by value..
# 1. Insert
# 2. Delete by value
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 56
#
# LinkedList - Delete by value..
# 1. Insert
# 2. Delete by value
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 32
#
# LinkedList - Delete by value..
# 1. Insert
# 2. Delete by value
# 3. Display
# 4. Exit
# Enter your choice: 3
# Linked List Elements:
# 12 -> 56 -> 32 -> None
#
# LinkedList - Delete by value..
# 1. Insert
# 2. Delete by value
# 3. Display
# 4. Exit
# Enter your choice: 2
# Enter the value to delete: 12
# 12 deleted from the list
#
# LinkedList - Delete by value..
# 1. Insert
# 2. Delete by value
# 3. Display
# 4. Exit
# Enter your choice: 3
# Linked List Elements:
# 56 -> 32 -> None
#
# LinkedList - Delete by value..
# 1. Insert
# ...

# %%
"Delete operation at beginning"


class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def iae(self, data):  # Insert at end
        newnode = Node(data)
        if self.head is None:
            self.head = newnode
            print(f"{data} inserted at end.")
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = newnode

    def deletebeign(self):
      if self.head is None:
        print("Empty LL")
      else:
        print(f"{self.head.data} deleted from the list")
        self.head = self.head.next

    def display(self):
      current = self.head
      if not current:
        print("Linked list is empty.")
        return
      print("Linked List Elements:")
      while current:
        print(current.data, end=" -> ")
        current = current.next
      print("None")
l1 = LinkedList()
while True:
    print("\nLinkedList - Delete at Begin...")
    print("1. Insert")
    print("2. Delete at begin")
    print("3. Display")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        data = int(input("Enter a value to insert: "))
        l1.iae(data)
    elif choice == '2':
        l1.deletebeign() # Fixed method call
    elif choice == '3':
        l1.display()
    elif choice == '4':
        print("Exiting the operation...")
        break
    else:
        print("Enter only 1/2/3/4")
# Out:
# LinkedList - Delete at Begin...
# 1. Insert
# 2. Delete at begin
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 21
# 21 inserted at end.
#
# LinkedList - Delete at Begin...
# 1. Insert
# 2. Delete at begin
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 43
#
# LinkedList - Delete at Begin...
# 1. Insert
# 2. Delete at begin
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 45
#
# LinkedList - Delete at Begin...
# 1. Insert
# 2. Delete at begin
# 3. Display
# 4. Exit
# Enter your choice: 3
# Linked List Elements:
# 21 -> 43 -> 45 -> None
#
# LinkedList - Delete at Begin...
# 1. Insert
# 2. Delete at begin
# 3. Display
# 4. Exit
# Enter your choice: 2
# 21 deleted from the list
#
# LinkedList - Delete at Begin...
# 1. Insert
# 2. Delete at begin
# 3. Display
# 4. Exit
# Enter your choice: 21
# Enter only 1/2/3/4
#
# LinkedList - Delete at Begin...
# 1. Insert
# 2. Delete at begin
# 3. Display
# 4. Exit
# ...

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def iae(self, data):  # Insert at end
        newnode = Node(data)
        if self.head is None:
            self.head = newnode
            print(f"{data} inserted at end.")
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = newnode
        print(f"{data} inserted at end.")

    def deleteatbegin(self):  # Delete from beginning
        if self.head is None:
            print("Empty Linked List.")
        else:
            print(f"{self.head.data} deleted from the list")
            self.head = self.head.next

    def display(self):
        current = self.head
        if not current:
            print("Linked list is empty.")
            return
        print("Linked List Elements:")
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

l1 = LinkedList()
while True:
    print("\nLinkedList - Delete at Beginning...")
    print("1. Insert")
    print("2. Delete at beginning")
    print("3. Display")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        data = int(input("Enter a value to insert: "))
        l1.iae(data)
    elif choice == '2':
        l1.deleteatbegin()
    elif choice == '3':
        l1.display()
    elif choice == '4':
        print("Exiting the operation...")
        break
    else:
        print("Enter only 1/2/3/4")
# Out:
# LinkedList - Delete at Beginning...
# 1. Insert
# 2. Delete at beginning
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 12
# 12 inserted at end.
#
# LinkedList - Delete at Beginning...
# 1. Insert
# 2. Delete at beginning
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 4
# 4 inserted at end.
#
# LinkedList - Delete at Beginning...
# 1. Insert
# 2. Delete at beginning
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 65
# 65 inserted at end.
#
# LinkedList - Delete at Beginning...
# 1. Insert
# 2. Delete at beginning
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 34
# 34 inserted at end.
#
# LinkedList - Delete at Beginning...
# 1. Insert
# 2. Delete at beginning
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 67
# 67 inserted at end.
#
# LinkedList - Delete at Beginning...
# 1. Insert
# 2. Delete at beginning
# 3. Display
# 4. Exit
# Enter your choice: 3
# ...

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def iae(self, data):  # Insert at end
        newnode = Node(data)
        if self.head is None:
            self.head = newnode
            print(f"{data} inserted at end.")
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = newnode
        print(f"{data} inserted at end.")

    def deleteend(self):
        if self.head is None:
            print("Empty Linked List.")
            return

        if self.head.next is None:
            print(f"{self.head.data} deleted from the list")
            self.head = None
            return

        current = self.head
        while current.next.next:
            current = current.next

        print(f"{current.next.data} deleted from the list")
        current.next = None

    def display(self):
        current = self.head
        if not current:
            print("Linked list is empty.")
            return
        print("Linked List Elements:")
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

l1 = LinkedList()
while True:
    print("\nLinkedList - Delete at end...")
    print("1. Insert")
    print("2. Delete at end")
    print("3. Display")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        data = int(input("Enter a value to insert: "))
        l1.iae(data)
    elif choice == '2':
        l1.deleteend()
    elif choice == '3':
        l1.display()
    elif choice == '4':
        print("Exiting the operation...")
        break
    else:
        print("Enter only 1/2/3/4")
# Out:
# LinkedList - Delete at end...
# 1. Insert
# 2. Delete at end
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 12
# 12 inserted at end.
#
# LinkedList - Delete at end...
# 1. Insert
# 2. Delete at end
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 23
# 23 inserted at end.
#
# LinkedList - Delete at end...
# 1. Insert
# 2. Delete at end
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 23
# 23 inserted at end.
#
# LinkedList - Delete at end...
# 1. Insert
# 2. Delete at end
# 3. Display
# 4. Exit
# Enter your choice: 3
# Linked List Elements:
# 12 -> 23 -> 23 -> None
#
# LinkedList - Delete at end...
# 1. Insert
# 2. Delete at end
# 3. Display
# 4. Exit
# Enter your choice: 12
# Enter only 1/2/3/4
#
# LinkedList - Delete at end...
# 1. Insert
# 2. Delete at end
# 3. Display
# 4. Exit
# Enter your choice: 2
# 23 deleted from the list
#
# LinkedList - Delete at end...
# 1. Insert
# 2. Delete at end
# 3. Display
# ...

# %% [markdown]
# #

# %%
class TransactionHistoryNode:
    def __init__(self,TransactioN_type,amount):
        self.TransactioN_type = TransactioN_type
        self.amount = amount
        self.next = None
class TransactionHistory:
    def __init__(self):
        self.head = None
    def add_transaction(self, transaction_type, amount):
        new_transaction = TransactionHistoryNode(transaction_type, amount)
        if self.head is None:
            self.head = new_transaction
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_transaction
        print(f"Transaction of {amount} {transaction_type} added to the history.")
    def show_history(self):
        if not self.head:
            print("No transactions in the history.")
            return
        print("Transaction History:")
        current = self.head
        count = 1
        while current:
          print(f"Transaction Type: {current.TransactioN_type}, Amount: {current.amount}")
          current = current.next
          count += 1



history = TransactionHistory()
while True:
  print("\n--- ATM Transaction Menu")
  print("1. Deposit")
  print("2. Withdraw")
  print("3. Transaction History")
  print("4. Exit")
  choice = input("Enter your choice: ")
  if choice == '1':
    amount = float(input("Enter the deposit amount: "))
    history.add_transaction("Deposit",amount)
  elif choice == '2':
    amount = float(input("Enter the withdrawal amount: "))
    history.add_transaction("Withdrawal",amount)
  elif choice == '3':
    history.show_history()
  elif choice == '4':
    print("End of Transcation...")
    break
  else:
    print("Enter only 1/2/3/4")
# Out:
# --- ATM Transaction Menu
# 1. Deposit
# 2. Withdraw
# 3. Transaction History
# 4. Exit
# Enter your choice: 1
# Enter the deposit amount: 1000
# Transaction of 1000.0 Deposit added to the history.
#
# --- ATM Transaction Menu
# 1. Deposit
# 2. Withdraw
# 3. Transaction History
# 4. Exit
# Enter your choice: 1
# Enter the deposit amount: 1500
# Transaction of 1500.0 Deposit added to the history.
#
# --- ATM Transaction Menu
# 1. Deposit
# 2. Withdraw
# 3. Transaction History
# 4. Exit
# Enter your choice: 1
# Enter the deposit amount: 1320
# Transaction of 1320.0 Deposit added to the history.
#
# --- ATM Transaction Menu
# 1. Deposit
# 2. Withdraw
# 3. Transaction History
# 4. Exit
# Enter your choice: 3
# Transaction History:
# Transaction Type: Deposit, Amount: 1000.0
# Transaction Type: Deposit, Amount: 1500.0
# Transaction Type: Deposit, Amount: 1320.0
#
# --- ATM Transaction Menu
# 1. Deposit
# 2. Withdraw
# 3. Transaction History
# 4. Exit
# Enter your choice: 2
# ...

# %% [markdown]
# #### consider a single linked list with insert at end nodes after insertion reverse the node to print
#
# ##### INPUT - 11 - 22 - 33 - 44 - 55 - NULL
# ##### OUTPUT - 55 - 44 - 33 - 22 - 11 - NULL

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def iae(self,data):
        newnode = Node(data)
        if self.head is None:
            self.head = newnode
            print(f"{data} inserted at end.")
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = newnode
        print(f"{data} inserted at end.")

    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev
        print("Linked list reversed.")

    def display(self):
        if self.head is None:
            print("Linked list is empty.")
            return
        current = self.head
        print("Linked List Elements:")
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

# Menu-driven code
l1 = LinkedList()
while True:
    print("\nLinkedList - Insert at End and Reverse")
    print("1. Insert at End")
    print("2. Reverse")
    print("3. Display")
    print("4. Exit")
    choice = input("Enter your choice: ")
    if choice == '1':
        data = int(input("Enter a value to insert: "))
        l1.iae(data)
    elif choice == '2':
        l1.reverse()
    elif choice == '3':
        l1.display()
    elif choice == '4':
        print("Exiting the operation...")
        break
    else:
        print("Enter only 1/2/3/4")
# Out:
# LinkedList - Insert at End and Reverse
# 1. Insert at End
# 2. Reverse
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 21
# 21 inserted at end.
#
# LinkedList - Insert at End and Reverse
# 1. Insert at End
# 2. Reverse
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 56
# 56 inserted at end.
#
# LinkedList - Insert at End and Reverse
# 1. Insert at End
# 2. Reverse
# 3. Display
# 4. Exit
# Enter your choice: 1
# Enter a value to insert: 78
# 78 inserted at end.
#
# LinkedList - Insert at End and Reverse
# 1. Insert at End
# 2. Reverse
# 3. Display
# 4. Exit
# Enter your choice: 2
# Linked list reversed.
#
# LinkedList - Insert at End and Reverse
# 1. Insert at End
# 2. Reverse
# 3. Display
# 4. Exit
# Enter your choice: 67
# Enter only 1/2/3/4
#
# LinkedList - Insert at End and Reverse
# 1. Insert at End
# 2. Reverse
# 3. Display
# 4. Exit
# Enter your choice: 3
# Linked List Elements:
# 78 -> 56 -> 21 -> None
#
# ...

# %% [markdown]
# # double LinkedList
#
# #### operations
# 1. insertion   -- at begin, end , position
# 2. deletion -- by value
# 3. traversal
#
# head <--> node1  <-->  node2 <--> node3 <---> null
#
# ###### node:
#    ##### class node:
#       def __init__(self,data):
#           self.data = data
#           self.next = None
#           self.prev = None

# %% [markdown]
# ## Insertion on double Linked list
# #### at the end of Insertion of double linked list

# %%
class Node:
  def __init__(self,data):
    self.data = data
    self.next = None
    self.prev = None

class DoublyLinkedList:
  def __init__(self):
    self.head = None
  def iae(self,data):
    newnode = Node(data)
    if self.head is None:
      self.head = newnode
      return
    temp = self.head
    while temp.next:
      temp = temp.next
    temp.next = newnode
    newnode.prev = temp
  def display(self):
    temp = self.head
    print("Doubly Linked List :")
    while temp:
      print(temp.data,end=" <--> ")
      temp = temp.next
    print("None")

dll= DoublyLinkedList()
n = int(input("enter the number of elements to insert at end : "))
for i in range(n):
  val=int(input(f"enter the element {i+1} : "))
  dll.iae(val)
dll.display()
# Out:
# enter the number of elements to insert at end : 5
# enter the element 1 : 88
# enter the element 2 : 21
# enter the element 3 : 34
# enter the element 4 : 54
# enter the element 5 : 56
# Doubly Linked List :
# 88 <--> 21 <--> 34 <--> 54 <--> 56 <--> None

# %% [markdown]
# ## insert at the begin

# %%
class Node:
  def __init__(self,data):
    self.data = data
    self.next = None
    self.prev = None
class DoublyLinkedList:
  def __init__(self):
    self.head = None
  def iab(self,data):
    newnode = Node(data)
    newnode.next = self.head
    self.head = newnode
   # print(f" {data} inserted from begin.")
  def display(self):
    temp = self.head
    print("Doubly Linked List :")
    while temp:
      print(temp.data,end=" <--> ")
      temp = temp.next
    print("None")

dll= DoublyLinkedList()
n = int(input("enter the number of elements to insert at begin : "))
for i in range(n):
  val=int(input(f"enter the element {i+1} : "))
  dll.iab(val)
dll.display()
# Out:
# enter the number of elements to insert at begin : 5
# enter the element 1 : 21
# enter the element 2 : 34
# enter the element 3 : 6
# enter the element 4 : 67
# enter the element 5 : 8
# Doubly Linked List :
# 8 <--> 67 <--> 6 <--> 34 <--> 21 <--> None

# %% [markdown]
# # Insertion at position

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def insert_at_position(self, data, pos):
        newnode = Node(data)
        if pos <= 0:
            print("Invalid position. Must be >= 1.")
            return
        if pos == 1:
            newnode.next = self.head
            if self.head is not None:
                self.head.prev = newnode
            self.head = newnode
            return
        current = self.head
        for _ in range(pos - 2):
            if current is None:
                print("Position out of bounds.")
                return
            current = current.next
        if current is None:
            print("Position out of bounds.")
            return
        newnode.next = current.next
        newnode.prev = current
        if current.next is not None:
            current.next.prev = newnode
        current.next = newnode

    def display(self):
        temp = self.head
        print("Doubly Linked List:")
        while temp:
            print(temp.data, end=" <--> ")
            temp = temp.next
        print("None")

# Main program
dll = DoublyLinkedList()
n = int(input("Enter the number of elements to insert at position: "))
for i in range(n):
    val = int(input(f"Enter element {i+1}: "))
    pos = int(input(f"Enter the position to insert {val} at: "))
    dll.insert_at_position(val, pos)

dll.display()
# Out:
# Enter the number of elements to insert at position: 3
# Enter element 1: 21
# Enter the position to insert 21 at: 1
# Enter element 2: 23
# Enter the position to insert 23 at: 3
# Position out of bounds.
# Enter element 3: 2
# Enter the position to insert 2 at: 2
# Doubly Linked List:
# 21 <--> 2 <--> None

# %% [markdown]
# ## Traversal of double LinkedList
# ### ex: 10   20   30
# ### o/p: 30 20 10

# %%
class Node:
  def __init__(self,data):
    self.data = data
    self.next = None
    self.prev = None
class DoublyLinkedList:
  def __init__(self):
    self.head = None
  def iae(self,data):
    newnode = Node(data)
    if self.head is None:
      self.head = newnode
      return
    temp = self.head
    while temp.next:
      temp = temp.next
    temp.next = newnode
    newnode.prev = temp
  def backtraverse(self):
    print("values for traversing backward")
    temp = self.head
    if not temp:
      print("empty list")
      return
    while temp.next:
      temp = temp.next
    while temp:
      print(temp.data,end=" <-->")
      temp = temp.prev
    print("None")
  def display(self):
    temp = self.head
    print("Doubly Linked List :")
    while temp:
      print(temp.data,end=" <-->  ")
      temp = temp.next
    print("None")

dll= DoublyLinkedList()
n = int(input("enter the number of elements to insert at end : "))
for i in range(n):
  val=int(input(f"enter the element {i+1} : "))
  dll.iae(val)
dll.display()
dll.backtraverse()
# Out:
# enter the number of elements to insert at end : 5
# enter the element 1 : 10
# enter the element 2 : 20
# enter the element 3 : 30
# enter the element 4 : 40
# enter the element 5 : 50
# Doubly Linked List :
# 10 <--> 20 <--> 30 <--> 40 <--> 50 <--> None
# values for traversing backward
# 50 <-->40 <-->30 <-->20 <-->10 <-->None

# %%
3class Node:
  def __init__(self,data):
    self.data = data
    self.next = None
    self.prev = None
class DoublyLinkedList:
  def __init__(self):
    self.head = None
  def iab(self,data):
    newnode = Node(data)
    newnode.next = self.head
    if self.head:
      self.head.prev = newnode
    self.head = newnode

  def backtraverse(self):
    print("values for traversing backward")
    temp = self.head
    if not temp:
      print("empty list")
      return
    while temp.next:
      temp = temp.next
    while temp:
      print(temp.data,end=" <-->")
      temp = temp.prev
    print("None")
  def display(self):
    temp = self.head
    print("Doubly Linked List :")
    while temp:
      print(temp.data,end=" <-->  ")
      temp = temp.next
    print("None")

dll= DoublyLinkedList()
n = int(input("enter the number of elements to insert at begin : "))
for i in range(n):
  val=int(input(f"enter the element {i+1} : "))
  dll.iab(val)
dll.display()
dll.backtraverse()
# Out:
# enter the number of elements to insert at begin : 3
# enter the element 1 : 11
# enter the element 2 : 22
# enter the element 3 : 33
# Doubly Linked List :
# 33 <-->  22 <-->  11 <-->  None
# values for traversing backward
# 11 <-->22 <-->33 <-->None
